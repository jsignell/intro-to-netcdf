# %% [markdown]
# This is a test of the netcdf files that we will be building from the USGS stream gage sites.

# %%
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
data_url = 'http://hydromet-thredds.princeton.edu:9000/thredds/dodsC/data/USGS_Stream_Gages/02146600.nc'
ds = xr.open_dataset(data_url)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                              (station_id: 1, time: 1629994)
# Coordinates:
#     lat                                  float64 ...
#     lon                                  float64 ...
#   * station_id                           (station_id) |S64 '02146600'
#     station_name                         |S64 ...
#   * time                                 (time) datetime64[ns] 1986-10-01T05:15:00 ...
# Data variables:
#     24_Hour_100_Year_Precipitation       (station_id) float64 ...
#     24_Hour_10_Year_Precipitation        (station_id) float64 ...
#     24_Hour_25_Year_Precipitation        (station_id) float64 ...
#     24_Hour_2_Year_Precipitation         (station_id) float64 ...
#     24_Hour_50_Year_Precipitation        (station_id) float64 ...
#     Basin_Drainage_Density               (station_id) float64 ...
#     Basin_Perimeter                      (station_id) float64 ...
#     Basin_Shape_Factor                   (station_id) float64 ...
#     Begin_date_of_record                 (station_id) timedelta64[ns] ...
#     Discharge                            (time) float64 ...
#     District_Code                        (station_id) float64 ...
#     Drainage_Area                        (station_id) float64 ...
#     Drainage_Quality_Index_from_STATSGO  (station_id) float64 ...
#     End_date_of_record                   (station_id) timedelta64[ns] ...
#     Latitude_of_Basin_Centroid           (station_id) float64 ...
#     Longitude_of_Basin_Centroid          (station_id) float64 ...
#     Main_Channel_Length                  (station_id) float64 ...
#     Maximum_Basin_Elevation              (station_id) float64 ...
#     Mean_Annual_Precipitation            (station_id) float64 ...
#     Mean_Basin_Elevation                 (station_id) float64 ...
#     Mean_Basin_Hydrologic_Soils_Index    (station_id) float64 ...
#     Mean_Basin_Slope_ft_per_ft           (station_id) float64 ...
#     Minimum_Basin_Elevation              (station_id) float64 ...
#     Number_of_days_GT_0                  (station_id) timedelta64[ns] ...
#     Number_of_days_of_record             (station_id) timedelta64[ns] ...
#     Percent_Forest                       (station_id) float64 ...
#     Percent_Impervious                   (station_id) float64 ...
# Attributes:
#     County: 119-Mecklenburg
#     Latitude_degrees_NAD83: 35.13778
#     Hydrologic_unit_code: 03050103
#     USGS_Station_Number: 02146600
#     Longitude_degrees_NAD83: -80.7675
#     Station_Name: MCALPINE CR AT SARDIS ROAD NEAR CHARLOTTE, NC
#     HCDN2009: No
#     featureType: timeSeries
#     Period_of_Record: April 1962 to current
#     Conventions: CF-1.6
#     Gage: None
#     Remarks: None
#     Regulation_and_Diversions: None
#     Regulated: False
#     Location: None
#     Station_Type: Streamgage, continuous record
#     metadata_source: http://ssdev.cr.usgs.gov/gagePages/html/02146600.htm
#     history: Created 2016-04-25 20:02:11.878385
#     DODS.strlen: 45
#     DODS.dimName: string45

# %%
ds.Drainage_Area
# Out:
# <xarray.DataArray 'Drainage_Area' (station_id: 1)>
# array([ 39.6])
# Coordinates:
#     lat           float64 ...
#     lon           float64 ...
#   * station_id    (station_id) |S64 '02146600'
#     station_name  |S64 ...
# Attributes:
#     units: square miles

# %%
fig = plt.figure(figsize=(14,5))
ds.Discharge.plot();
